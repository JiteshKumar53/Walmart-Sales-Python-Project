# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('C:\\Users\\Jitesh Kumar\\Downloads\\Walmart_Project\\Walmart.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
df
# Out:
#       Store                 Date  Weekly_Sales  Holiday_Flag  Temperature  \
# 0         1  2010-05-02 00:00:00    1643690.90             0        42.31
# 1         1  2010-12-02 00:00:00    1641957.44             1        38.51
# 2         1           19-02-2010    1611968.17             0        39.93
# 3         1           26-02-2010    1409727.59             0        46.63
# 4         1  2010-05-03 00:00:00    1554806.68             0        46.50
# ...     ...                  ...           ...           ...          ...
# 6430     45           28-09-2012     713173.95             0        64.88
# 6431     45  2012-05-10 00:00:00     733455.07             0        64.89
# 6432     45  2012-12-10 00:00:00     734464.36             0        54.47
# 6433     45           19-10-2012     718125.53             0        56.47
# 6434     45           26-10-2012     760281.43             0        58.85
#
#       Fuel_Price         CPI  Unemployment
# ...

# %%
#convert store into string

df['Store']=df['Store'].astype(str)

# %%
average_weekly_sales_by_store=df.groupby('Store')['Weekly_Sales'].mean().reset_index()
average_weekly_sales_by_store['Weekly_Sales'] /= 1000000
average_weekly_sales_by_store
# Out:
#    Store  Weekly_Sales
# 0      1      1.555264
# 1     10      1.899425
# 2     11      1.356383
# 3     12      1.009002
# 4     13      2.003620
# 5     14      2.020978
# 6     15      0.623312
# 7     16      0.519248
# 8     17      0.893581
# 9     18      1.084718
# 10    19      1.444999
# 11     2      1.925751
# 12    20      2.107677
# 13    21      0.756069
# 14    22      1.028501
# 15    23      1.389864
# 16    24      1.356755
# 17    25      0.706722
# 18    26      1.002912
# 19    27      1.775216
# 20    28      1.323522
# 21    29      0.539451
# 22     3      0.402704
# 23    30      0.438580
# 24    31      1.395901
# 25    32      1.166568
# 26    33      0.259862
# 27    34      0.966782
# 28    35      0.919725
# 29    36      0.373512
# 30    37      0.518900
# 31    38      0.385732
# 32    39      1.450668
# 33     4      2.094713
# 34    40      0.964128
# 35    41      1.268125
# 36    42      0.556404
# 37    43      0.633325
# 38    44      0.302749
# ...

# %%
plt.figure(figsize=(20,6))
import matplotlib.pyplot as plt
plt.bar(average_weekly_sales_by_store['Store'],average_weekly_sales_by_store['Weekly_Sales'],color='green')
plt.title('Weekly Sales Chart')
plt.xlabel('Stores')
plt.ylabel('Weekly Sales')
plt.show()

# %%
df_sort = average_weekly_sales_by_store.sort_values(by='Weekly_Sales',ascending=False)
df_sort
# Out:
#    Store  Weekly_Sales
# 12    20      2.107677
# 33     4      2.094713
# 5     14      2.020978
# 4     13      2.003620
# 11     2      1.925751
# 1     10      1.899425
# 19    27      1.775216
# 41     6      1.564728
# 0      1      1.555264
# 32    39      1.450668
# 10    19      1.444999
# 24    31      1.395901
# 15    23      1.389864
# 16    24      1.356755
# 2     11      1.356383
# 20    28      1.323522
# 35    41      1.268125
# 25    32      1.166568
# 9     18      1.084718
# 14    22      1.028501
# 3     12      1.009002
# 18    26      1.002912
# 27    34      0.966782
# 34    40      0.964128
# 28    35      0.919725
# 43     8      0.908750
# 8     17      0.893581
# 39    45      0.785981
# 13    21      0.756069
# 17    25      0.706722
# 37    43      0.633325
# 6     15      0.623312
# 42     7      0.570617
# 36    42      0.556404
# 44     9      0.543981
# 21    29      0.539451
# 7     16      0.519248
# 30    37      0.518900
# 23    30      0.438580
# ...

# %%
Top_5_stores=df_sort.head(5)
Top_5_stores
# Out:
#    Store  Weekly_Sales
# 12    20      2.107677
# 33     4      2.094713
# 5     14      2.020978
# 4     13      2.003620
# 11     2      1.925751

# %%
Bottom_5_stores=df_sort.head(5)
Bottom_5_stores
# Out:
#    Store  Weekly_Sales
# 12    20      2.107677
# 33     4      2.094713
# 5     14      2.020978
# 4     13      2.003620
# 11     2      1.925751

# %%
plt.figure(figsize=(8,3))
plt.bar(Top_5_stores['Store'],Top_5_stores['Weekly_Sales'],color='g')
plt.title('Top 5 Stores')
plt.xlabel('Stores')
plt.ylabel('Weekly Sales')
plt.show()

# %%
plt.figure(figsize=(8,3))
plt.bar(Bottom_5_stores['Store'],Bottom_5_stores['Weekly_Sales'],color='r')
plt.title('Bottom 5 stores')
plt.xlabel('Sales')
plt.ylabel('Weekly Sales')
plt.show()

# %%
df
# Out:
#      Store                 Date  Weekly_Sales  Holiday_Flag  Temperature  \
# 0        1  2010-05-02 00:00:00    1643690.90             0        42.31
# 1        1  2010-12-02 00:00:00    1641957.44             1        38.51
# 2        1           19-02-2010    1611968.17             0        39.93
# 3        1           26-02-2010    1409727.59             0        46.63
# 4        1  2010-05-03 00:00:00    1554806.68             0        46.50
# ...    ...                  ...           ...           ...          ...
# 6430    45           28-09-2012     713173.95             0        64.88
# 6431    45  2012-05-10 00:00:00     733455.07             0        64.89
# 6432    45  2012-12-10 00:00:00     734464.36             0        54.47
# 6433    45           19-10-2012     718125.53             0        56.47
# 6434    45           26-10-2012     760281.43             0        58.85
#
#       Fuel_Price         CPI  Unemployment
# 0          2.572  211.096358         8.106
# ...

# %%
#Bar chat as per Holiday Sales
average_weekly_sales_by_Holiday= df.groupby('Holiday_Flag')['Weekly_Sales'].mean().reset_index()
average_weekly_sales_by_Holiday['Weekly_Sales']/=1000000
average_weekly_sales_by_Holiday
# Out:
#    Holiday_Flag  Weekly_Sales
# 0             0      1.041256
# 1             1      1.122888

# %%
plt.figure(figsize=(6,4))
plt.bar(average_weekly_sales_by_Holiday['Holiday_Flag'],average_weekly_sales_by_Holiday['Weekly_Sales'])
plt.title('Sales on Holidays')
plt.xlabel('')
plt.xticks([0,1],['No Holiday','Holiday'])
plt.ylabel('Weekly Sales')
plt.show()

# %%
df.head(5)
# Out:
#   Store                 Date  Weekly_Sales  Holiday_Flag  Temperature  \
# 0     1  2010-05-02 00:00:00    1643690.90             0        42.31
# 1     1  2010-12-02 00:00:00    1641957.44             1        38.51
# 2     1           19-02-2010    1611968.17             0        39.93
# 3     1           26-02-2010    1409727.59             0        46.63
# 4     1  2010-05-03 00:00:00    1554806.68             0        46.50
#
#    Fuel_Price         CPI  Unemployment
# 0       2.572  211.096358         8.106
# 1       2.548  211.242170         8.106
# 2       2.514  211.289143         8.106
# 3       2.561  211.319643         8.106
# 4       2.625  211.350143         8.106

# %%
Selected_columns=(['Weekly_Sales','Holiday_Flag','Temperature','Fuel_Price','CPI','Unemployment'])
Selected_df=df[Selected_columns]
Selected_df
# Out:
#       Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0       1643690.90             0        42.31       2.572  211.096358
# 1       1641957.44             1        38.51       2.548  211.242170
# 2       1611968.17             0        39.93       2.514  211.289143
# 3       1409727.59             0        46.63       2.561  211.319643
# 4       1554806.68             0        46.50       2.625  211.350143
# ...            ...           ...          ...         ...         ...
# 6430     713173.95             0        64.88       3.997  192.013558
# 6431     733455.07             0        64.89       3.985  192.170412
# 6432     734464.36             0        54.47       4.000  192.327265
# 6433     718125.53             0        56.47       3.969  192.330854
# 6434     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment
# 0            8.106
# 1            8.106
# 2            8.106
# 3            8.106
# 4            8.106
# ...

# %%
Realation_matrix=Selected_df.corr()
Realation_matrix
# Out:
#               Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price       CPI  \
# Weekly_Sales      1.000000      0.036891    -0.063810    0.009464 -0.072634
# Holiday_Flag      0.036891      1.000000    -0.155091   -0.078347 -0.002162
# Temperature      -0.063810     -0.155091     1.000000    0.144982  0.176888
# Fuel_Price        0.009464     -0.078347     0.144982    1.000000 -0.170642
# CPI              -0.072634     -0.002162     0.176888   -0.170642  1.000000
# Unemployment     -0.106176      0.010960     0.101158   -0.034684 -0.302020
#
#               Unemployment
# Weekly_Sales     -0.106176
# Holiday_Flag      0.010960
# Temperature       0.101158
# Fuel_Price       -0.034684
# CPI              -0.302020
# Unemployment      1.000000

# %%
plt.figure(figsize=(5,4))
sns.heatmap(Realation_matrix,annot=True,cmap='coolwarm',linewidths=0.5)
plt.title('Realation Chart')
plt.show()
#Fuel Price and Weekly Sales

# %%
df.head(10)
# Out:
#   Store                 Date  Weekly_Sales  Holiday_Flag  Temperature  \
# 0     1  2010-05-02 00:00:00    1643690.90             0        42.31
# 1     1  2010-12-02 00:00:00    1641957.44             1        38.51
# 2     1           19-02-2010    1611968.17             0        39.93
# 3     1           26-02-2010    1409727.59             0        46.63
# 4     1  2010-05-03 00:00:00    1554806.68             0        46.50
# 5     1  2010-12-03 00:00:00    1439541.59             0        57.79
# 6     1           19-03-2010    1472515.79             0        54.58
# 7     1           26-03-2010    1404429.92             0        51.45
# 8     1  2010-02-04 00:00:00    1594968.28             0        62.27
# 9     1  2010-09-04 00:00:00    1545418.53             0        65.86
#
#    Fuel_Price         CPI  Unemployment
# 0       2.572  211.096358         8.106
# 1       2.548  211.242170         8.106
# 2       2.514  211.289143         8.106
# ...

# %%
df['Month']= df['Date'].dt.strftime('%B')

# %%
df.head(5)
# Out:
#   Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0     1 2010-05-02    1643690.90             0        42.31       2.572
# 1     1 2010-12-02    1641957.44             1        38.51       2.548
# 2     1 2010-02-19    1611968.17             0        39.93       2.514
# 3     1 2010-02-26    1409727.59             0        46.63       2.561
# 4     1 2010-05-03    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment     Month
# 0  211.096358         8.106       May
# 1  211.242170         8.106  December
# 2  211.289143         8.106  February
# 3  211.319643         8.106  February
# 4  211.350143         8.106       May

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Month',y='Weekly_Sales',data=df)
plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()
# Highest sales was in december

# %%
df['Year']= df['Date'].dt.year

# %%
df.head(5)
# Out:
#   Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0     1 2010-05-02    1643690.90             0        42.31       2.572
# 1     1 2010-12-02    1641957.44             1        38.51       2.548
# 2     1 2010-02-19    1611968.17             0        39.93       2.514
# 3     1 2010-02-26    1409727.59             0        46.63       2.561
# 4     1 2010-05-03    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment     Month  Year
# 0  211.096358         8.106       May  2010
# 1  211.242170         8.106  December  2010
# 2  211.289143         8.106  February  2010
# 3  211.319643         8.106  February  2010
# 4  211.350143         8.106       May  2010

# %%
plt.figure(figsize=(5,4))
sns.barplot(x='Year',y='Weekly_Sales',data=df)
plt.title('Yearly Sales')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.show()
